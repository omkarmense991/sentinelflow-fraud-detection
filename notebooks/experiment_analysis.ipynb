# %%
import pandas as pd

# %%
results = pd.read_csv(
    "../artifacts/metrics/experiment_results.csv"
)

results
# Out:
#                      timestamp                model       sampling  precision  \
# 0   2026-05-20T00:03:04.292692  logistic_regression           none   0.027347
# 1   2026-05-20T00:03:17.535909        random_forest           none   0.922222
# 2   2026-05-20T00:03:18.306027              xgboost           none   0.908046
# 3   2026-05-20T00:03:18.498284  logistic_regression  undersampling   0.024443
# 4   2026-05-20T00:03:18.767180        random_forest  undersampling   0.014536
# 5   2026-05-20T00:03:19.048313              xgboost  undersampling   0.026346
# 6   2026-05-20T00:03:20.917943  logistic_regression   oversampling   0.027422
# 7   2026-05-20T00:03:39.027912        random_forest   oversampling   0.881720
# 8   2026-05-20T00:03:40.214784              xgboost   oversampling   0.639706
# 9   2026-05-20T00:03:41.897889  logistic_regression          smote   0.072299
# 10  2026-05-20T00:04:26.845601        random_forest          smote   0.679688
# ...

# %%
results.sort_values(
    by="pr_auc",
    ascending=False
)
# Out:
#                      timestamp                model       sampling  precision  \
# 10  2026-05-20T00:04:26.845601        random_forest          smote   0.679688
# 8   2026-05-20T00:03:40.214784              xgboost   oversampling   0.639706
# 11  2026-05-20T00:04:28.142475              xgboost          smote   0.354839
# 2   2026-05-20T00:03:18.306027              xgboost           none   0.908046
# 7   2026-05-20T00:03:39.027912        random_forest   oversampling   0.881720
# 1   2026-05-20T00:03:17.535909        random_forest           none   0.922222
# 9   2026-05-20T00:03:41.897889  logistic_regression          smote   0.072299
# 0   2026-05-20T00:03:04.292692  logistic_regression           none   0.027347
# 6   2026-05-20T00:03:20.917943  logistic_regression   oversampling   0.027422
# 4   2026-05-20T00:03:18.767180        random_forest  undersampling   0.014536
# 5   2026-05-20T00:03:19.048313              xgboost  undersampling   0.026346
# ...
